# %% [markdown]
# # GloFAS download

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
from src.datasources import glofas

# %%
glofas.download_reanalysis()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# already downloaded for 2003
# already downloaded for 2004
# already downloaded for 2005
# already downloaded for 2006
# already downloaded for 2007
# already downloaded for 2008
# already downloaded for 2009
# already downloaded for 2010
# already downloaded for 2011
# already downloaded for 2012
# already downloaded for 2013
# already downloaded for 2014
# already downloaded for 2015
# already downloaded for 2016
# already downloaded for 2017
# already downloaded for 2018
# already downloaded for 2019
# already downloaded for 2020
# already downloaded for 2021
# already downloaded for 2022
# already downloaded for 2023

# %%
glofas.download_reforecast_ensembles()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 24-120, already exists
# Skipping 2004 24-120, already exists
# Skipping 2005 24-120, already exists
# Skipping 2006 24-120, already exists
# Skipping 2007 24-120, already exists
# Skipping 2008 24-120, already exists
# Skipping 2009 24-120, already exists
# Skipping 2010 24-120, already exists
# Skipping 2011 24-120, already exists
# Skipping 2012 24-120, already exists
# Skipping 2013 24-120, already exists
# Skipping 2014 24-120, already exists
# Skipping 2015 24-120, already exists
# Skipping 2016 24-120, already exists
# Skipping 2017 24-120, already exists
# Skipping 2018 24-120, already exists
# Skipping 2019 24-120, already exists
# Skipping 2020 24-120, already exists
# Skipping 2021 24-120, already exists
# Skipping 2022 24-120, already exists
# 2025-07-25 16:53:55,137 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-25 16:53:55,143 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-25 16:53:55,144 WARNING [2025-07-25T23:53:55.159409] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-25T23:53:55.159409] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-25 16:53:55,146 INFO Request ID is 0b032301-8865-4657-b69a-f597be85ac04
# INFO:cads_api_client.processing:Request ID is 0b032301-8865-4657-b69a-f597be85ac04
# 2025-07-25 16:53:55,359 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-25 16:54:08,419 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# WARNING:multiurl.http:Recovering from connection error [HTTPSConnectionPool(host='ewds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/0b032301-8865-4657-b69a-f597be85ac04?log=True (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1080635d0>: Failed to resolve 'ewds.climate.copernicus.eu' ([Errno 8] nodename nor servname provided, or not known)"))], attemps 2 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-25 22:42:54,194 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 5a866df085b34cc2e93e9c93412248de.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 144-240, already exists
# Skipping 2004 144-240, already exists
# Skipping 2005 144-240, already exists
# Skipping 2006 144-240, already exists
# Skipping 2007 144-240, already exists
# Skipping 2008 144-240, already exists
# Skipping 2009 144-240, already exists
# Skipping 2010 144-240, already exists
# Skipping 2011 144-240, already exists
# Skipping 2012 144-240, already exists
# Skipping 2013 144-240, already exists
# Skipping 2014 144-240, already exists
# Skipping 2015 144-240, already exists
# Skipping 2016 144-240, already exists
# Skipping 2017 144-240, already exists
# Skipping 2018 144-240, already exists
# Skipping 2019 144-240, already exists
# Skipping 2020 144-240, already exists
# Skipping 2021 144-240, already exists
# Skipping 2022 144-240, already exists
# 2025-07-25 22:42:57,881 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-25 22:42:57,884 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-25 22:42:57,887 WARNING [2025-07-26T05:42:57.811900] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-26T05:42:57.811900] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-25 22:42:57,891 INFO Request ID is 4ee07be1-8827-4930-8d3c-b830876217af
# INFO:cads_api_client.processing:Request ID is 4ee07be1-8827-4930-8d3c-b830876217af
# 2025-07-25 22:42:58,094 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-25 22:43:05,871 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-26 04:26:19,937 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# a7099e2d73ee6960a01b91d839ee5a3a.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 264-360, already exists
# Skipping 2004 264-360, already exists
# Skipping 2005 264-360, already exists
# Skipping 2006 264-360, already exists
# Skipping 2007 264-360, already exists
# Skipping 2008 264-360, already exists
# Skipping 2009 264-360, already exists
# Skipping 2010 264-360, already exists
# Skipping 2011 264-360, already exists
# Skipping 2012 264-360, already exists
# Skipping 2013 264-360, already exists
# Skipping 2014 264-360, already exists
# Skipping 2015 264-360, already exists
# Skipping 2016 264-360, already exists
# Skipping 2017 264-360, already exists
# Skipping 2018 264-360, already exists
# Skipping 2019 264-360, already exists
# Skipping 2020 264-360, already exists
# Skipping 2021 264-360, already exists
# Skipping 2022 264-360, already exists
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-26 09:16:41,444 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 09:16:41,450 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 09:16:41,451 WARNING [2025-07-26T16:16:41.380086] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-26T16:16:41.380086] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 09:16:41,457 INFO Request ID is 625c8a0a-09ec-4682-adbd-8f454add92ba
# INFO:cads_api_client.processing:Request ID is 625c8a0a-09ec-4682-adbd-8f454add92ba
# 2025-07-26 09:16:41,675 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-26 13:05:37,911 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 944766b854b01eb544973dfd48992d0f.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 384-480, already exists
# Skipping 2004 384-480, already exists
# Skipping 2005 384-480, already exists
# Skipping 2006 384-480, already exists
# Skipping 2007 384-480, already exists
# Skipping 2008 384-480, already exists
# Skipping 2009 384-480, already exists
# Skipping 2010 384-480, already exists
# Skipping 2011 384-480, already exists
# Skipping 2012 384-480, already exists
# Skipping 2013 384-480, already exists
# Skipping 2014 384-480, already exists
# Skipping 2015 384-480, already exists
# Skipping 2016 384-480, already exists
# Skipping 2017 384-480, already exists
# Skipping 2018 384-480, already exists
# Skipping 2019 384-480, already exists
# Skipping 2020 384-480, already exists
# Skipping 2021 384-480, already exists
# Skipping 2022 384-480, already exists
# 2025-07-26 13:05:41,591 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 13:05:41,593 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 13:05:41,593 WARNING [2025-07-26T20:05:41.508964] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-26T20:05:41.508964] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 13:05:41,594 INFO Request ID is 79c52708-b2a1-4964-8f26-0d71437d813b
# INFO:cads_api_client.processing:Request ID is 79c52708-b2a1-4964-8f26-0d71437d813b
# 2025-07-26 13:05:41,792 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 13:06:02,528 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-26 14:32:21,930 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 1b1dfed6877f339f7ce34ea7e38893a4.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 504-600, already exists
# Skipping 2004 504-600, already exists
# Skipping 2005 504-600, already exists
# Skipping 2006 504-600, already exists
# Skipping 2007 504-600, already exists
# Skipping 2008 504-600, already exists
# Skipping 2009 504-600, already exists
# Skipping 2010 504-600, already exists
# Skipping 2011 504-600, already exists
# Skipping 2012 504-600, already exists
# Skipping 2013 504-600, already exists
# Skipping 2014 504-600, already exists
# Skipping 2015 504-600, already exists
# Skipping 2016 504-600, already exists
# Skipping 2017 504-600, already exists
# Skipping 2018 504-600, already exists
# Skipping 2019 504-600, already exists
# Skipping 2020 504-600, already exists
# Skipping 2021 504-600, already exists
# Skipping 2022 504-600, already exists
# 2025-07-26 14:32:25,505 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 14:32:25,508 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 14:32:25,510 WARNING [2025-07-26T21:32:25.443433] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-26T21:32:25.443433] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 14:32:25,512 INFO Request ID is 654768b8-cc62-4667-9bea-cd4f50ea461c
# INFO:cads_api_client.processing:Request ID is 654768b8-cc62-4667-9bea-cd4f50ea461c
# 2025-07-26 14:32:25,722 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 14:32:38,890 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-26 18:35:49,336 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 1d079a84c02e68b129760b4b651e5a5b.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 624-720, already exists
# Skipping 2004 624-720, already exists
# Skipping 2005 624-720, already exists
# Skipping 2006 624-720, already exists
# Skipping 2007 624-720, already exists
# Skipping 2008 624-720, already exists
# Skipping 2009 624-720, already exists
# Skipping 2010 624-720, already exists
# Skipping 2011 624-720, already exists
# Skipping 2012 624-720, already exists
# Skipping 2013 624-720, already exists
# Skipping 2014 624-720, already exists
# Skipping 2015 624-720, already exists
# Skipping 2016 624-720, already exists
# Skipping 2017 624-720, already exists
# Skipping 2018 624-720, already exists
# Skipping 2019 624-720, already exists
# Skipping 2020 624-720, already exists
# Skipping 2021 624-720, already exists
# Skipping 2022 624-720, already exists
# 2025-07-26 18:35:53,131 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 18:35:53,137 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 18:35:53,138 WARNING [2025-07-27T01:35:53.057437] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T01:35:53.057437] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 18:35:53,139 INFO Request ID is e7215e7a-1542-4269-a216-a44547a069f8
# INFO:cads_api_client.processing:Request ID is e7215e7a-1542-4269-a216-a44547a069f8
# 2025-07-26 18:35:53,350 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 18:36:06,372 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attemps 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-07-26 19:29:05,909 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# d64f367f13492c733da1038b382ae17.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 744-840, already exists
# Skipping 2004 744-840, already exists
# Skipping 2005 744-840, already exists
# Skipping 2006 744-840, already exists
# Skipping 2007 744-840, already exists
# Skipping 2008 744-840, already exists
# Skipping 2009 744-840, already exists
# Skipping 2010 744-840, already exists
# Skipping 2011 744-840, already exists
# Skipping 2012 744-840, already exists
# Skipping 2013 744-840, already exists
# Skipping 2014 744-840, already exists
# Skipping 2015 744-840, already exists
# Skipping 2016 744-840, already exists
# Skipping 2017 744-840, already exists
# Skipping 2018 744-840, already exists
# Skipping 2019 744-840, already exists
# Skipping 2020 744-840, already exists
# Skipping 2021 744-840, already exists
# Skipping 2022 744-840, already exists
# 2025-07-26 19:29:09,196 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 19:29:09,197 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 19:29:09,198 WARNING [2025-07-27T02:29:09.150080] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T02:29:09.150080] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 19:29:09,200 INFO Request ID is 70c2ddfd-b969-459e-b95f-ff11caf2eefe
# INFO:cads_api_client.processing:Request ID is 70c2ddfd-b969-459e-b95f-ff11caf2eefe
# 2025-07-26 19:29:09,406 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 19:29:22,562 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-26 20:29:46,666 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# a925169661101737d5cc7f26921cfec0.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 864-960, already exists
# Skipping 2004 864-960, already exists
# Skipping 2005 864-960, already exists
# Skipping 2006 864-960, already exists
# Skipping 2007 864-960, already exists
# Skipping 2008 864-960, already exists
# Skipping 2009 864-960, already exists
# Skipping 2010 864-960, already exists
# Skipping 2011 864-960, already exists
# Skipping 2012 864-960, already exists
# Skipping 2013 864-960, already exists
# Skipping 2014 864-960, already exists
# Skipping 2015 864-960, already exists
# Skipping 2016 864-960, already exists
# Skipping 2017 864-960, already exists
# Skipping 2018 864-960, already exists
# Skipping 2019 864-960, already exists
# Skipping 2020 864-960, already exists
# Skipping 2021 864-960, already exists
# Skipping 2022 864-960, already exists
# 2025-07-26 20:29:50,574 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 20:29:50,576 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 20:29:50,577 WARNING [2025-07-27T03:29:50.500160] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T03:29:50.500160] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 20:29:50,578 INFO Request ID is 263609c2-c5c6-4ccb-9f4d-aff0eda2a75b
# INFO:cads_api_client.processing:Request ID is 263609c2-c5c6-4ccb-9f4d-aff0eda2a75b
# 2025-07-26 20:29:50,765 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 20:29:58,655 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-26 20:30:03,925 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 20:30:23,542 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-26 21:40:31,595 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# b2e953d1cd20526e0814dd8e1fd67971.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 984-1080, already exists
# Skipping 2004 984-1080, already exists
# Skipping 2005 984-1080, already exists
# Skipping 2006 984-1080, already exists
# Skipping 2007 984-1080, already exists
# Skipping 2008 984-1080, already exists
# Skipping 2009 984-1080, already exists
# Skipping 2010 984-1080, already exists
# Skipping 2011 984-1080, already exists
# Skipping 2012 984-1080, already exists
# Skipping 2013 984-1080, already exists
# Skipping 2014 984-1080, already exists
# Skipping 2015 984-1080, already exists
# Skipping 2016 984-1080, already exists
# Skipping 2017 984-1080, already exists
# Skipping 2018 984-1080, already exists
# Skipping 2019 984-1080, already exists
# Skipping 2020 984-1080, already exists
# Skipping 2021 984-1080, already exists
# Skipping 2022 984-1080, already exists
# 2025-07-26 21:40:34,729 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 21:40:34,731 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 21:40:34,733 WARNING [2025-07-27T04:40:34.657636] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T04:40:34.657636] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 21:40:34,734 INFO Request ID is db2deccf-7c1d-4156-bf03-0220d94e5986
# INFO:cads_api_client.processing:Request ID is db2deccf-7c1d-4156-bf03-0220d94e5986
# 2025-07-26 21:40:34,934 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 21:40:42,706 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-26 22:35:10,732 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# ddd4fe49b730dc32056ad7b701162eb1.grib:   0%|          | 0.00/615k [00:00<?, ?B/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping 2003 1104-1104, already exists
# Skipping 2004 1104-1104, already exists
# Skipping 2005 1104-1104, already exists
# Skipping 2006 1104-1104, already exists
# Skipping 2007 1104-1104, already exists
# Skipping 2008 1104-1104, already exists
# Skipping 2009 1104-1104, already exists
# Skipping 2010 1104-1104, already exists
# Skipping 2011 1104-1104, already exists
# Skipping 2012 1104-1104, already exists
# Skipping 2013 1104-1104, already exists
# Skipping 2014 1104-1104, already exists
# Skipping 2015 1104-1104, already exists
# 2025-07-26 22:35:14,360 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 22:35:14,362 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 22:35:14,363 WARNING [2025-07-27T05:35:14.282157] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T05:35:14.282157] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 22:35:14,364 INFO Request ID is 602988d6-95ce-4f45-84f8-d1d20cae0f48
# INFO:cads_api_client.processing:Request ID is 602988d6-95ce-4f45-84f8-d1d20cae0f48
# 2025-07-26 22:35:14,583 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 22:35:27,642 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-26 23:25:49,875 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 50ef3fd01c9d3136be444beb40d752b.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-26 23:25:52,651 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-26 23:25:52,654 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-26 23:25:52,656 WARNING [2025-07-27T06:25:52.572309] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T06:25:52.572309] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-26 23:25:52,658 INFO Request ID is 544aaf35-1398-4c57-8d25-b6bacbb4d596
# INFO:cads_api_client.processing:Request ID is 544aaf35-1398-4c57-8d25-b6bacbb4d596
# 2025-07-26 23:25:52,877 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-26 23:26:05,981 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 00:16:27,229 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# cca4478ca5db5ce427d08bc6ea6d3cb1.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-27 00:16:30,673 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-27 00:16:30,676 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-27 00:16:30,677 WARNING [2025-07-27T07:16:30.586208] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T07:16:30.586208] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-27 00:16:30,678 INFO Request ID is bd8a40c8-4966-483b-bc25-1d59a0dbf66c
# INFO:cads_api_client.processing:Request ID is bd8a40c8-4966-483b-bc25-1d59a0dbf66c
# 2025-07-27 00:16:30,948 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-27 00:16:39,070 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 01:01:03,809 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# b7533b087cba55095e9eac2bffaa90b8.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-27 01:01:06,636 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-27 01:01:06,639 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-27 01:01:06,641 WARNING [2025-07-27T08:01:06.549053] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T08:01:06.549053] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-27 01:01:06,643 INFO Request ID is cc164780-eaa7-4f6d-9089-5f6836a9b847
# INFO:cads_api_client.processing:Request ID is cc164780-eaa7-4f6d-9089-5f6836a9b847
# 2025-07-27 01:01:06,843 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-27 01:01:19,893 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 01:43:38,525 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# c753e2f327712131f5d7bc9adc621205.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-27 01:43:41,805 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-27 01:43:41,807 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-27 01:43:41,808 WARNING [2025-07-27T08:43:41.739139] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T08:43:41.739139] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-27 01:43:41,809 INFO Request ID is e35475ae-46ee-4a48-b5ca-bfa8febbaf05
# INFO:cads_api_client.processing:Request ID is e35475ae-46ee-4a48-b5ca-bfa8febbaf05
# 2025-07-27 01:43:42,053 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-27 01:43:49,868 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 02:30:15,316 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 240a7beaf20a7d5b3c9e32cfd52746f0.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-27 02:30:18,114 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-27 02:30:18,116 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-27 02:30:18,116 WARNING [2025-07-27T09:30:18.037987] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T09:30:18.037987] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-27 02:30:18,117 INFO Request ID is ba609bd0-d3ec-4a21-bcfd-71567ffc9718
# INFO:cads_api_client.processing:Request ID is ba609bd0-d3ec-4a21-bcfd-71567ffc9718
# 2025-07-27 02:30:18,338 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-27 02:30:31,571 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 03:24:54,530 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 7a27a2a1c157caacfbc8dd573882f121.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-27 03:24:57,863 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-27 03:24:57,865 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-27 03:24:57,865 WARNING [2025-07-27T10:24:57.788524] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T10:24:57.788524] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-27 03:24:57,866 INFO Request ID is dadcd26f-85ca-4420-a161-f565c880d68e
# INFO:cads_api_client.processing:Request ID is dadcd26f-85ca-4420-a161-f565c880d68e
# 2025-07-27 03:24:58,064 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-27 03:25:11,229 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 04:09:30,616 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 29728f00f47b59c678a84a773525a059.grib:   0%|          | 0.00/251k [00:00<?, ?B/s]
# 2025-07-27 04:09:33,735 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-07-27 04:09:33,739 INFO [2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# INFO:cads_api_client.processing:[2024-11-11T00:00:00] Temporary freeze of medium-range reforecasts available from the EWDS, with no update of the dataset from GloFAS v4.2 release date. If you require access to the reforecast data, please get in touch with us via the [ECMWF Support Portal](https://confluence.ecmwf.int/site/support) using the title 'Access to GloFAS Reforecast Data' when creating the ticket. Information on how to raise a ticket in our support portal is available
# [here](https://confluence.ecmwf.int/display/CEMS/CEMS-Flood+Data+Support).
# 2025-07-27 04:09:33,741 WARNING [2025-07-27T11:09:33.673877] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# WARNING:cads_api_client.processing:[2025-07-27T11:09:33.673877] You are using a deprecated API endpoint. If you are using cdsapi, please upgrade to the latest version.
# 2025-07-27 04:09:33,743 INFO Request ID is 190d8508-0463-493d-b5a3-9f31fb896844
# INFO:cads_api_client.processing:Request ID is 190d8508-0463-493d-b5a3-9f31fb896844
# 2025-07-27 04:09:34,233 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2025-07-27 04:09:47,273 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2025-07-27 04:52:05,815 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 7591255fe706ec33d3dfe07afec2ec1e.grib:   0%|          | 0.00/123k [00:00<?, ?B/s]
