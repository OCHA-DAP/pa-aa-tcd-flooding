# %% [markdown]
# # GloFAS forecast download

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
from src.datasources import glofas

# %%
glofas.download_forecast_ensembles()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 2024-08-14 12:12:45,652 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2024-08-14 12:12:45,656 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2024-08-14 12:12:45,658 INFO Request ID is 360c7bea-8827-4b8a-a3f5-4515e4055f4f
# INFO:cads_api_client.processing:Request ID is 360c7bea-8827-4b8a-a3f5-4515e4055f4f
# 2024-08-14 12:12:45,874 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-14 12:17:05,830 INFO status has been updated to failed
# INFO:cads_api_client.processing:status has been updated to failed
# Failed to download 24
# The job has failed.
# The job failed with: MarsRuntimeError
# MARS has returned an error, please check your selection.
# Request submitted to the MARS server:
# [{'area': [12.135000000000002, 15.014999999999999, 12.114999999999998, 15.035000000000002], 'model': ['global_lisflood'], 'step': ['24'], 'type': ['pf'], 'expver': ['1'], 'param': '240024', 'time': ['00:00:00'], 'class': ['ce'], 'expect': ['any'], 'number': ['all'], 'origin': ['ecmf'], 'stream': ['wfas'], 'levtype': ['sfc'], 'database': 'ecmwf', 'interpolation': '--area-mode=mask', 'date': ['2023-06-01', '2023-06-05', '2023-06-08', '2023-06-12', '2023-06-15', '2023-06-19', '2023-06-22', '2023-06-26', '2023-06-29', '2023-07-01', '2023-07-05', '2023-07-08', '2023-07-12', '2023-07-15', '2023-07-19', '2023-07-22', '2023-07-26', '2023-07-29', '2023-08-01', '2023-08-05', '2023-08-08', '2023-08-12', '2023-08-15', '2023-08-19', '2023-08-22', '2023-08-26', '2023-08-29', '2023-09-01', '2023-09-05', '2023-09-08', '2023-09-12', '2023-09-15', '2023-09-19', '2023-09-22', '2023-09-26', '2023-09-29', '2023-10-01', '2023-10-05', '2023-10-08', '2023-10-12', '2023-10-15', '2023-10-19', '2023-10-22', '2023-10-26', '2023-10-29', '2023-11-01', '2023-11-05', '2023-11-08', '2023-11-12', '2023-11-15', '2023-11-19', '2023-11-22', '2023-11-26', '2023-11-29']}]
# Full error message:
# mars - ERROR  - 20240814.191556 - Exception: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191556 - MIR: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191556 - Interpolation failed (-2)
# mars - ERROR  - 20240814.191556 - Mars server task finished in error
# mars - ERROR  - 20240814.191556 - Double buffer error: Assertion failed: length == buffers_[i].length_ in run, line 292 of /home/deploy/git/mars-server/eckit/src/eckit/io/DblBuffer.cc(RemoteException from Connector[mvr012,bods1-ag0721:9701]) [marser-ecmwf]
# mars - ERROR  - 20240814.191556 - Error code is -2
# mars - ERROR  - 20240814.191556 - Request failed
# mars - ERROR  - 20240814.191556 - Some errors reported (last error -2)
# 2024-08-14 12:17:06,723 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2024-08-14 12:17:06,725 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2024-08-14 12:17:06,727 INFO Request ID is 8dded0f2-a7dd-46e5-b5d3-3bdade485c08
# INFO:cads_api_client.processing:Request ID is 8dded0f2-a7dd-46e5-b5d3-3bdade485c08
# 2024-08-14 12:17:06,933 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-14 12:17:56,662 INFO status has been updated to failed
# INFO:cads_api_client.processing:status has been updated to failed
# Failed to download 48
# The job has failed.
# MARS has returned an error, please check your selection.
# Request submitted to the MARS server:
# [{'area': [12.135000000000002, 15.014999999999999, 12.114999999999998, 15.035000000000002], 'model': ['global_lisflood'], 'step': ['48'], 'type': ['pf'], 'expver': ['1'], 'param': '240024', 'time': ['00:00:00'], 'class': ['ce'], 'expect': ['any'], 'number': ['all'], 'origin': ['ecmf'], 'stream': ['wfas'], 'levtype': ['sfc'], 'database': 'ecmwf', 'interpolation': '--area-mode=mask', 'date': ['2023-06-01', '2023-06-05', '2023-06-08', '2023-06-12', '2023-06-15', '2023-06-19', '2023-06-22', '2023-06-26', '2023-06-29', '2023-07-01', '2023-07-05', '2023-07-08', '2023-07-12', '2023-07-15', '2023-07-19', '2023-07-22', '2023-07-26', '2023-07-29', '2023-08-01', '2023-08-05', '2023-08-08', '2023-08-12', '2023-08-15', '2023-08-19', '2023-08-22', '2023-08-26', '2023-08-29', '2023-09-01', '2023-09-05', '2023-09-08', '2023-09-12', '2023-09-15', '2023-09-19', '2023-09-22', '2023-09-26', '2023-09-29', '2023-10-01', '2023-10-05', '2023-10-08', '2023-10-12', '2023-10-15', '2023-10-19', '2023-10-22', '2023-10-26', '2023-10-29', '2023-11-01', '2023-11-05', '2023-11-08', '2023-11-12', '2023-11-15', '2023-11-19', '2023-11-22', '2023-11-26', '2023-11-29']}]
# Full error message:
# mars - ERROR  - 20240814.191748 - Exception: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191748 - MIR: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191748 - Interpolation failed (-2)
# mars - ERROR  - 20240814.191748 - Mars server task finished in error
# mars - ERROR  - 20240814.191748 - Double buffer error: Assertion failed: length == buffers_[i].length_ in run, line 292 of /home/deploy/git/mars-server/eckit/src/eckit/io/DblBuffer.cc(RemoteException from Connector[mvr012,bods1-ag0721:9701]) [marser-ecmwf]
# mars - ERROR  - 20240814.191748 - Error code is -2
# mars - ERROR  - 20240814.191748 - Request failed
# mars - ERROR  - 20240814.191748 - Some errors reported (last error -2)
#
# The job failed with: MarsRuntimeError
# 2024-08-14 12:17:57,517 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2024-08-14 12:17:57,519 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2024-08-14 12:17:57,519 INFO Request ID is 7ce02b14-db65-4784-a3e2-ec204a2815c7
# INFO:cads_api_client.processing:Request ID is 7ce02b14-db65-4784-a3e2-ec204a2815c7
# 2024-08-14 12:17:57,717 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-14 12:18:47,451 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2024-08-14 12:19:13,344 INFO status has been updated to failed
# INFO:cads_api_client.processing:status has been updated to failed
# Failed to download 72
# The job has failed.
# The job failed with: MarsRuntimeError
# MARS has returned an error, please check your selection.
# Request submitted to the MARS server:
# [{'area': [12.135000000000002, 15.014999999999999, 12.114999999999998, 15.035000000000002], 'model': ['global_lisflood'], 'step': ['72'], 'type': ['pf'], 'expver': ['1'], 'param': '240024', 'time': ['00:00:00'], 'class': ['ce'], 'expect': ['any'], 'number': ['all'], 'origin': ['ecmf'], 'stream': ['wfas'], 'levtype': ['sfc'], 'database': 'ecmwf', 'interpolation': '--area-mode=mask', 'date': ['2023-06-01', '2023-06-05', '2023-06-08', '2023-06-12', '2023-06-15', '2023-06-19', '2023-06-22', '2023-06-26', '2023-06-29', '2023-07-01', '2023-07-05', '2023-07-08', '2023-07-12', '2023-07-15', '2023-07-19', '2023-07-22', '2023-07-26', '2023-07-29', '2023-08-01', '2023-08-05', '2023-08-08', '2023-08-12', '2023-08-15', '2023-08-19', '2023-08-22', '2023-08-26', '2023-08-29', '2023-09-01', '2023-09-05', '2023-09-08', '2023-09-12', '2023-09-15', '2023-09-19', '2023-09-22', '2023-09-26', '2023-09-29', '2023-10-01', '2023-10-05', '2023-10-08', '2023-10-12', '2023-10-15', '2023-10-19', '2023-10-22', '2023-10-26', '2023-10-29', '2023-11-01', '2023-11-05', '2023-11-08', '2023-11-12', '2023-11-15', '2023-11-19', '2023-11-22', '2023-11-26', '2023-11-29']}]
# Full error message:
# mars - ERROR  - 20240814.191847 - Exception: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191847 - MIR: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191847 - Interpolation failed (-2)
# mars - ERROR  - 20240814.191847 - Mars server task finished in error
# mars - ERROR  - 20240814.191847 - Double buffer error: Assertion failed: length == buffers_[i].length_ in run, line 292 of /home/deploy/git/mars-server/eckit/src/eckit/io/DblBuffer.cc(RemoteException from Connector[mvr012,bods1-ag0721:9701]) [marser-ecmwf]
# mars - ERROR  - 20240814.191847 - Error code is -2
# mars - ERROR  - 20240814.191847 - Request failed
# mars - ERROR  - 20240814.191847 - Some errors reported (last error -2)
# 2024-08-14 12:19:14,242 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2024-08-14 12:19:14,246 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2024-08-14 12:19:14,250 INFO Request ID is 8d6f2f28-04c4-47dc-bf65-f29cbf069ac3
# INFO:cads_api_client.processing:Request ID is 8d6f2f28-04c4-47dc-bf65-f29cbf069ac3
# 2024-08-14 12:19:14,462 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-14 12:19:35,328 INFO status has been updated to failed
# INFO:cads_api_client.processing:status has been updated to failed
# Failed to download 96
# The job has failed.
# MARS has returned an error, please check your selection.
# Request submitted to the MARS server:
# [{'area': [12.135000000000002, 15.014999999999999, 12.114999999999998, 15.035000000000002], 'model': ['global_lisflood'], 'step': ['96'], 'type': ['pf'], 'expver': ['1'], 'param': '240024', 'time': ['00:00:00'], 'class': ['ce'], 'expect': ['any'], 'number': ['all'], 'origin': ['ecmf'], 'stream': ['wfas'], 'levtype': ['sfc'], 'database': 'ecmwf', 'interpolation': '--area-mode=mask', 'date': ['2023-06-01', '2023-06-05', '2023-06-08', '2023-06-12', '2023-06-15', '2023-06-19', '2023-06-22', '2023-06-26', '2023-06-29', '2023-07-01', '2023-07-05', '2023-07-08', '2023-07-12', '2023-07-15', '2023-07-19', '2023-07-22', '2023-07-26', '2023-07-29', '2023-08-01', '2023-08-05', '2023-08-08', '2023-08-12', '2023-08-15', '2023-08-19', '2023-08-22', '2023-08-26', '2023-08-29', '2023-09-01', '2023-09-05', '2023-09-08', '2023-09-12', '2023-09-15', '2023-09-19', '2023-09-22', '2023-09-26', '2023-09-29', '2023-10-01', '2023-10-05', '2023-10-08', '2023-10-12', '2023-10-15', '2023-10-19', '2023-10-22', '2023-10-26', '2023-10-29', '2023-11-01', '2023-11-05', '2023-11-08', '2023-11-12', '2023-11-15', '2023-11-19', '2023-11-22', '2023-11-26', '2023-11-29']}]
# Full error message:
# mars - ERROR  - 20240814.191930 - Exception: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191930 - MIR: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.191930 - Interpolation failed (-2)
# mars - ERROR  - 20240814.191930 - Mars server task finished in error
# mars - ERROR  - 20240814.191930 - Double buffer error: Assertion failed: length == buffers_[i].length_ in run, line 292 of /home/deploy/git/mars-server/eckit/src/eckit/io/DblBuffer.cc(RemoteException from Connector[mvr012,bods1-ag0721:9701]) [marser-ecmwf]
# mars - ERROR  - 20240814.191930 - Error code is -2
# mars - ERROR  - 20240814.191930 - Request failed
# mars - ERROR  - 20240814.191930 - Some errors reported (last error -2)
#
# The job failed with: MarsRuntimeError
# 2024-08-14 12:19:36,202 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2024-08-14 12:19:36,204 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2024-08-14 12:19:36,206 INFO Request ID is 4b49aa05-3442-4282-9744-a2aed2a5edd5
# INFO:cads_api_client.processing:Request ID is 4b49aa05-3442-4282-9744-a2aed2a5edd5
# 2024-08-14 12:19:36,408 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-14 12:20:26,127 INFO status has been updated to failed
# INFO:cads_api_client.processing:status has been updated to failed
# Failed to download 120
# The job has failed.
# MARS has returned an error, please check your selection.
# Request submitted to the MARS server:
# [{'area': [12.135000000000002, 15.014999999999999, 12.114999999999998, 15.035000000000002], 'model': ['global_lisflood'], 'step': ['120'], 'type': ['pf'], 'expver': ['1'], 'param': '240024', 'time': ['00:00:00'], 'class': ['ce'], 'expect': ['any'], 'number': ['all'], 'origin': ['ecmf'], 'stream': ['wfas'], 'levtype': ['sfc'], 'database': 'ecmwf', 'interpolation': '--area-mode=mask', 'date': ['2023-06-01', '2023-06-05', '2023-06-08', '2023-06-12', '2023-06-15', '2023-06-19', '2023-06-22', '2023-06-26', '2023-06-29', '2023-07-01', '2023-07-05', '2023-07-08', '2023-07-12', '2023-07-15', '2023-07-19', '2023-07-22', '2023-07-26', '2023-07-29', '2023-08-01', '2023-08-05', '2023-08-08', '2023-08-12', '2023-08-15', '2023-08-19', '2023-08-22', '2023-08-26', '2023-08-29', '2023-09-01', '2023-09-05', '2023-09-08', '2023-09-12', '2023-09-15', '2023-09-19', '2023-09-22', '2023-09-26', '2023-09-29', '2023-10-01', '2023-10-05', '2023-10-08', '2023-10-12', '2023-10-15', '2023-10-19', '2023-10-22', '2023-10-26', '2023-10-29', '2023-11-01', '2023-11-05', '2023-11-08', '2023-11-12', '2023-11-15', '2023-11-19', '2023-11-22', '2023-11-26', '2023-11-29']}]
# Full error message:
# mars - ERROR  - 20240814.192021 - Exception: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.192021 - MIR: Assertion failed: Area: non-empty area crop/mask (to at least one point) in apply, line 103 of /home/deploy/git/mars-client/mir/src/mir/action/area/Area.cc
# mars - ERROR  - 20240814.192021 - Interpolation failed (-2)
# mars - ERROR  - 20240814.192021 - Mars server task finished in error
# mars - ERROR  - 20240814.192021 - Double buffer error: Assertion failed: length == buffers_[i].length_ in run, line 292 of /home/deploy/git/mars-server/eckit/src/eckit/io/DblBuffer.cc(RemoteException from Connector[mvr012,bods1-ag0721:9701]) [marser-ecmwf]
# mars - ERROR  - 20240814.192021 - Error code is -2
# mars - ERROR  - 20240814.192021 - Request failed
# mars - ERROR  - 20240814.192021 - Some errors reported (last error -2)
#
# The job failed with: MarsRuntimeError
# 2024-08-14 12:20:27,062 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2024-08-14 12:20:27,064 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:cads_api_client.processing:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2024-08-14 12:20:27,066 INFO Request ID is b362e23d-a2f6-4eff-8a54-ce03909c911e
# INFO:cads_api_client.processing:Request ID is b362e23d-a2f6-4eff-8a54-ce03909c911e
# 2024-08-14 12:20:27,269 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-14 12:23:19,852 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 glofas.download_forecast_ensembles()
#
# File ~/OCHA/repos/pa-aa-tcd-flooding/src/datasources/glofas.py:108, in download_forecast_ensembles()
#     106     continue
#     107 try:
# --> 108     c.retrieve(
#     109         dataset,
#     110         {
#     111             "system_version": ["operational"],
#     112             "hydrological_model": ["lisflood"],
#     113             "product_type": ["ensemble_perturbed_forecasts"],
#     114             "variable": "river_discharge_in_the_last_24_hours",
#     115             "year": ["2023"],
#     116             "month": [f"{x:02}" for x in range(6, 12)],
#     117             "day": [f"{x:02}" for x in days],
#     118             "leadtime_hour": [str(leadtime)],
#     119             "data_format": "grib2",
#     120             "download_format": "unarchived",
#     121             "area": [
#     122                 N + extend_pitch,
#     123                 W - extend_pitch,
#     124                 S - extend_pitch,
#     125                 E + extend_pitch,
#     126             ],
#     127         },
#     128         save_path,
#     129     )
#     130 except Exception as e:
#     131     print(f"Failed to download {leadtime}")
#
# File ~/.pyenv/versions/pa-aa-tcd-flooding/lib/python3.11/site-packages/cads_api_client/legacy_api_client.py:149, in LegacyApiClient.retrieve(self, name, request, target)
#     146 def retrieve(
#     147     self, name: str, request: dict[str, Any], target: str | None = None
#     148 ) -> str | processing.Results:
# --> 149     result = self.logging_decorator(self.client.submit_and_wait_on_result)(
#     150         collection_id=name,
#     151         retry_options=self.retry_options,
#     152         **request,
#     153     )
#     154     partial_download: Callable[..., str] = functools.partial(
#     155         result.download,
#     156         timeout=self.timeout,
#     157         retry_options=self.retry_options,
#     158     )
#     159     result.download = self.logging_decorator(partial_download)  # type: ignore[method-assign]
#
# File ~/.pyenv/versions/pa-aa-tcd-flooding/lib/python3.11/site-packages/cads_api_client/legacy_api_client.py:134, in LegacyApiClient.logging_decorator.<locals>.wrapper(*args, **kwargs)
#     129 @functools.wraps(func)
#     130 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     131     with LoggingContext(
#     132         logger=processing.logger, quiet=self.quiet, debug=self._debug
#     133     ):
# --> 134         return func(*args, **kwargs)
#
# File ~/.pyenv/versions/pa-aa-tcd-flooding/lib/python3.11/site-packages/cads_api_client/api_client.py:77, in ApiClient.submit_and_wait_on_result(self, collection_id, retry_options, **request)
#      74 def submit_and_wait_on_result(
#      75     self, collection_id: str, retry_options: Dict[str, Any] = {}, **request: Any
#      76 ) -> processing.Results:
# ---> 77     return self.retrieve_api.submit_and_wait_on_result(
#      78         collection_id, retry_options=retry_options, **request
#      79     )
#
# File ~/.pyenv/versions/pa-aa-tcd-flooding/lib/python3.11/site-packages/cads_api_client/processing.py:454, in Processing.submit_and_wait_on_result(self, collection_id, retry_options, **request)
#     450 def submit_and_wait_on_result(
#     451     self, collection_id: str, retry_options: Dict[str, Any] = {}, **request: Any
#     452 ) -> Results:
#     453     remote = self.submit(collection_id, retry_options=retry_options, **request)
# --> 454     remote.wait_on_result(retry_options=retry_options)
#     455     return remote.make_results()
#
# File ~/.pyenv/versions/pa-aa-tcd-flooding/lib/python3.11/site-packages/cads_api_client/processing.py:248, in Remote.wait_on_result(self, retry_options)
#     246     raise ProcessingFailedError(f"Unknown API state {status!r}")
#     247 logger.debug(f"result not ready, waiting for {sleep} seconds")
# --> 248 time.sleep(sleep)
#
# KeyboardInterrupt:
